# %%
import pandas as pd

# %%
math_written_df = pd.read_csv('../../data/umimematikucz-system_written_answer_data.csv', delimiter = ';')
math_resource_df = pd.read_csv('../../data/umimematikucz-system_resource_set.csv', delimiter = ';')
inf_binary_df = pd.read_csv('../../data/umimeprogramovatcz-system_binary_choice_data.csv', delimiter = ';')
inf_resource_df = pd.read_csv('../../data/umimeprogramovatcz-system_resource_set.csv', delimiter = ';')

# %%
math_written_df
# Out:
#           id    rs  difficultyRank  \
# 0          1  1099               1
# 1          2  1103               1
# 2          3  1099               1
# 3          4  1103               1
# 4          5  1099               1
# ...      ...   ...             ...
# 14249  16148   773               2
# 14250  16149   773               2
# 14251  16150   773               2
# 14252  16151   773               2
# 14253  16152   773               2
#
#                                                 question commonWrongAnswer  \
# 0      [["latex","1+1"], ["input",{"answer":["2"],"st...                 1
# 1      [["latex","2-1"],["input",{"answer":["1"],"sty...                 3
# 2      [["latex","1+2"],["input",{"answer":["3"],"sty...                 2
# 3      [["latex","3-2"],["input",{"answer":["1"],"sty...                 5
# 4      [["latex","1+3"],["input",{"answer":["4"],"sty...                 3
# ...                                                  ...               ...
# 14249  [["latex","7 \\cdot (2x +2)=-42"], ["input",{"...               NaN
# 14250  [["latex","(x -5):7=3"], ["input",{"answer":["...               NaN
# 14251  [["latex","3=(x -5):2"], ["input",{"answer":["...               NaN
# 14252  [["latex","(-2 + x):3=6"], ["input",{"answer":...               NaN
# 14253  [["latex","-2=(-3 + x):6"], ["input",{"answer"...               NaN
#
#        translation                                        explanation  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# ...            ...                                                ...
# 14249          NaN  [["latex","7 \\cdot (2x +2)=-42"], ["text"," V...
# 14250          NaN  [["latex","(x -5):7=3"], ["text"," Vynásobíme ...
# 14251          NaN  [["latex","3=(x -5):2"], ["text"," Vynásobíme ...
# 14252          NaN  [["latex","(-2 + x):3=6"], ["text"," Vynásobím...
# 14253          NaN  [["latex","-2=(-3 + x):6"], ["text"," Vynásobí...
#
#                    created           lastUpdate        masterUpdated  \
# 0      2017-05-15 11:41:42  2025-02-20 21:16:49  0000-00-00 00:00:00
# 1      2017-05-15 11:41:42  2017-05-15 11:41:42  0000-00-00 00:00:00
# 2      2017-05-15 11:41:42  2017-05-15 11:41:42  0000-00-00 00:00:00
# 3      2017-05-15 11:41:42  2017-05-15 11:41:42  0000-00-00 00:00:00
# 4      2017-05-15 11:41:42  2017-05-15 11:41:42  0000-00-00 00:00:00
# ...                    ...                  ...                  ...
# 14249  2026-02-17 11:09:09  2026-02-17 11:09:09  0000-00-00 00:00:00
# 14250  2026-02-17 11:09:11  2026-02-17 11:09:11  0000-00-00 00:00:00
# 14251  2026-02-17 11:09:12  2026-02-17 11:09:12  0000-00-00 00:00:00
# 14252  2026-02-17 11:09:13  2026-02-17 11:09:13  0000-00-00 00:00:00
# 14253  2026-02-17 11:09:14  2026-02-17 11:09:14  0000-00-00 00:00:00
#
#        checkTranslate  visible
# 0                   0        1
# 1                   0        1
# 2                   0        1
# 3                   0        1
# 4                   0        1
# ...               ...      ...
# 14249               0        1
# 14250               0        1
# 14251               0        1
# 14252               0        1
# 14253               0        1
#
# [14254 rows x 12 columns]

# %%
math_resource_df
# Out:
#        id  parent           type                            name  shortName  \
# 0     226      15   binaryChoice                             NaN        NaN
# 1     227      15   binaryChoice  [["text","Odhad počtu teček"]]        NaN
# 2     228      16   binaryChoice                             NaN        NaN
# 3     229     158   binaryChoice                             NaN        NaN
# 4     230     151   binaryChoice                             NaN        NaN
# ..    ...     ...            ...                             ...        ...
# 735  1237     468   binaryChoice                             NaN        NaN
# 736  1238     152   binaryChoice                             NaN        NaN
# 737  1239     152   binaryChoice                             NaN        NaN
# 738  1240     534  writtenAnswer                             NaN        NaN
# 739  1241     534  writtenAnswer                             NaN        NaN
#
#                                               shortcut  explanation  \
# 0                                   bc-pocitani-do-100          NaN
# 1                                 bc-odhad-poctu-tecek          NaN
# 2                          bc-porovnavani-cisel-do-100          NaN
# 3                                      bc-cisla-slovne          NaN
# 4                bc-zaokrouhlovani-na-desitky-a-stovky          NaN
# ..                                                 ...          ...
# 735                             bc-development-02-2026          NaN
# 736  bc-zaokrouhlovani-desetinnych-cisel-desetinna-...          NaN
# 737  bc-zaokrouhlovani-desetinnych-cisel-na-desitky...          NaN
# 738         wa-nasobilky-jednocifernych-cisel-a-10-mix          NaN
# 739                      wa-nasobilky-cisel-2-az-5-mix          NaN
#
#                                                  specs aggregationType
# 0                                                  NaN           basic
# 1                                                  NaN           basic
# 2                                                  NaN           basic
# 3                                                  NaN           basic
# 4                                                  NaN           basic
# ..                                                 ...             ...
# 735                                                NaN           basic
# 736                                                NaN           basic
# 737                                                NaN           basic
# 738  {"rs":["wa-mala-nasobilka-cislo-2","wa-mala-na...             mix
# 739  {"rs":["wa-mala-nasobilka-cislo-2","wa-mala-na...             mix
#
# [740 rows x 9 columns]
